# %% [markdown]
# <a href="https://colab.research.google.com/github/lfo13-ui/bte320/blob/main/BTE_320_in_class_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("enter sales value ($): "))

cogs = .4 * sales
gross_profit = sales - cogs
print(f"sales: {sales}$")
print(f"cost of goods sold: {cogs}$")
print(f"gross profit: {gross_profit}$")
# Out:
# enter sales value ($): 12000
# sales: 12000.0$
# cost of goods sold: 4800.0$
# gross profit: 7200.0$
